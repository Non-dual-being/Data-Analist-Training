# %%
import pandas as pd

path = r"C:\Users\Stichting GeoFort\Downloads\laptop_prices.csv"

# %%
df = pd.read_csv(path, encoding='ISO-8859-1')

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df.query('Price_usd > 1200')
# Out:
#       laptop_ID Company            Product            TypeName  Inches  \
# 0             1   Apple        MacBook Pro           Ultrabook    13.3
# 3             4   Apple        MacBook Pro           Ultrabook    15.4
# 4             5   Apple        MacBook Pro           Ultrabook    13.3
# 6             7   Apple        MacBook Pro           Ultrabook    15.4
# 7             8   Apple        Macbook Air           Ultrabook    13.3
# ...         ...     ...                ...                 ...     ...
# 1256       1274    Asus  Rog G752VT-GC073T              Gaming    17.3
# 1259       1277     MSI        GE62 Apache              Gaming    15.6
# 1271       1289  Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1285       1303  Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1299       1317  Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
#
#                                 ScreenResolution                          Cpu  \
# ...

# %%
df.columns
# Out:
# Index(['laptop_ID', 'Company', 'Product', 'TypeName', 'Inches',
#        'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight',
#        'Price_usd'],
#       dtype='object')

# %%
df.query('Price_usd > 1200 and Company == "Apple" and Ram == "8GB"')
# Out:
#       laptop_ID Company      Product   TypeName  Inches  \
# 0             1   Apple  MacBook Pro  Ultrabook    13.3
# 4             5   Apple  MacBook Pro  Ultrabook    13.3
# 7             8   Apple  Macbook Air  Ultrabook    13.3
# 14           15   Apple  MacBook 12"  Ultrabook    12.0
# 15           16   Apple  MacBook Pro  Ultrabook    13.3
# 26           27   Apple  MacBook Air  Ultrabook    13.3
# 45           46   Apple  MacBook Pro  Ultrabook    13.3
# 81           83   Apple  MacBook 12"  Ultrabook    12.0
# 249         254   Apple  MacBook Pro  Ultrabook    13.3
# 270         275   Apple  MacBook Pro  Ultrabook    13.3
# 794         803   Apple  MacBook 12"  Ultrabook    12.0
# 1069       1084   Apple  MacBook 12"  Ultrabook    12.0
# 1193       1211   Apple  MacBook 12"  Ultrabook    12.0
# 1210       1228   Apple  MacBook 12"  Ultrabook    12.0
#
#                         ScreenResolution                     Cpu  Ram  \
# ...

# %%
import pandasql as psql

# %%
psql.sqldf("SELECT * FROM df WHERE Company = 'Apple'")
# Out:
#     laptop_ID Company      Product   TypeName  Inches  \
# 0           1   Apple  MacBook Pro  Ultrabook    13.3
# 1           2   Apple  Macbook Air  Ultrabook    13.3
# 2           4   Apple  MacBook Pro  Ultrabook    15.4
# 3           5   Apple  MacBook Pro  Ultrabook    13.3
# 4           7   Apple  MacBook Pro  Ultrabook    15.4
# 5           8   Apple  Macbook Air  Ultrabook    13.3
# 6          13   Apple  MacBook Pro  Ultrabook    15.4
# 7          15   Apple  MacBook 12"  Ultrabook    12.0
# 8          16   Apple  MacBook Pro  Ultrabook    13.3
# 9          18   Apple  MacBook Pro  Ultrabook    15.4
# 10         27   Apple  MacBook Air  Ultrabook    13.3
# 11         35   Apple  MacBook Air  Ultrabook    13.3
# 12         46   Apple  MacBook Pro  Ultrabook    13.3
# 13         83   Apple  MacBook 12"  Ultrabook    12.0
# 14        254   Apple  MacBook Pro  Ultrabook    13.3
# 15        275   Apple  MacBook Pro  Ultrabook    13.3
# ...

# %%
path_2 = r"C:\Users\Stichting GeoFort\Downloads\WorldContinents.csv"

# %%
df_2 = pd.read_csv(path_2, encoding= "ISO-8859-1")

# %%
df_2
# Out:
#     continent       sub_region            country code_3     Unnamed: 4
# 0        Asia    Southern Asia        Afghanistan    AFG     6,900,000
# 1      Europe  Northern Europe      Åland Islands    ALA     5,500,000
# 2      Europe  Southern Europe            Albania    ALB     3,300,000
# 3      Africa  Northern Africa            Algeria    DZA     9,500,000
# 4     Oceania        Polynesia     American Samoa    ASM        55,000
# ..        ...              ...                ...    ...            ...
# 235   Oceania        Polynesia  Wallis and Futuna    WLF    15,900,000
# 236    Africa  Northern Africa     Western Sahara    ESH       597,000
# 237      Asia     Western Asia              Yemen    YEM     5,500,000
# 238    Africa   Eastern Africa             Zambia    ZMB   213,000,000
# 239    Africa   Eastern Africa           Zimbabwe    ZWE    19,100,000
#
# [240 rows x 5 columns]

# %%
df_2 = df_2.rename(columns={'Unnamed: 4': 'Population'})

# %%
df_2
# Out:
#     continent       sub_region            country code_3     Population
# 0        Asia    Southern Asia        Afghanistan    AFG     6,900,000
# 1      Europe  Northern Europe      Åland Islands    ALA     5,500,000
# 2      Europe  Southern Europe            Albania    ALB     3,300,000
# 3      Africa  Northern Africa            Algeria    DZA     9,500,000
# 4     Oceania        Polynesia     American Samoa    ASM        55,000
# ..        ...              ...                ...    ...            ...
# 235   Oceania        Polynesia  Wallis and Futuna    WLF    15,900,000
# 236    Africa  Northern Africa     Western Sahara    ESH       597,000
# 237      Asia     Western Asia              Yemen    YEM     5,500,000
# 238    Africa   Eastern Africa             Zambia    ZMB   213,000,000
# 239    Africa   Eastern Africa           Zimbabwe    ZWE    19,100,000
#
# [240 rows x 5 columns]

# %%
df_world = pd.read_csv(path_2, index_col = 'country', encoding= "ISO-8859-1")

df_world
# Out:
#                   continent       sub_region code_3     Unnamed: 4
# country
# Afghanistan            Asia    Southern Asia    AFG     6,900,000
# Åland Islands        Europe  Northern Europe    ALA     5,500,000
# Albania              Europe  Southern Europe    ALB     3,300,000
# Algeria              Africa  Northern Africa    DZA     9,500,000
# American Samoa      Oceania        Polynesia    ASM        55,000
# ...                     ...              ...    ...            ...
# Wallis and Futuna   Oceania        Polynesia    WLF    15,900,000
# Western Sahara       Africa  Northern Africa    ESH       597,000
# Yemen                  Asia     Western Asia    YEM     5,500,000
# Zambia               Africa   Eastern Africa    ZMB   213,000,000
# Zimbabwe             Africa   Eastern Africa    ZWE    19,100,000
#
# [240 rows x 4 columns]

# %%
df_world = df_world.rename(columns={'Unnamed: 4': 'Population'})

df_world
# Out:
#                   continent       sub_region code_3     Population
# country
# Afghanistan            Asia    Southern Asia    AFG     6,900,000
# Åland Islands        Europe  Northern Europe    ALA     5,500,000
# Albania              Europe  Southern Europe    ALB     3,300,000
# Algeria              Africa  Northern Africa    DZA     9,500,000
# American Samoa      Oceania        Polynesia    ASM        55,000
# ...                     ...              ...    ...            ...
# Wallis and Futuna   Oceania        Polynesia    WLF    15,900,000
# Western Sahara       Africa  Northern Africa    ESH       597,000
# Yemen                  Asia     Western Asia    YEM     5,500,000
# Zambia               Africa   Eastern Africa    ZMB   213,000,000
# Zimbabwe             Africa   Eastern Africa    ZWE    19,100,000
#
# [240 rows x 4 columns]

# %%
df_world.loc['Albania']
# Out:
# continent              Europe
# sub_region    Southern Europe
# code_3                    ALB
# Population         3,300,000
# Name: Albania, dtype: object

# %%
df_pop = pd.read_csv(path_2, encoding= "ISO-8859-1")

df_pop.columns
# Out:
# Index(['continent', 'sub_region', 'country', 'code_3', 'Unnamed: 4'], dtype='object')

# %%
df_pop = df_pop.sort_values(by=['continent','sub_region'])

# %%
df_pop.set_index(['continent','sub_region'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21568\1725364407.py in ?()
# ----> 1 df_pop.set_index(['continent','sub_region'], inplace=True)
#
# c:\Users\Stichting GeoFort\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6105                     if not found:
#    6106                         missing.append(col)
#    6107
#    6108         if missing:
# -> 6109             raise KeyError(f"None of {missing} are in the columns")
#    6110
#    6111         if inplace:
#    6112             frame = self
#
# KeyError: "None of ['continent', 'sub_region'] are in the columns"

# %%
df_pop
# Out:
#                                     country code_3     Unnamed: 4
# continent sub_region
# Africa    Eastern Africa            Burundi    BDI   128,000,000
#           Eastern Africa            Comoros    COM       870,000
#           Eastern Africa           Djibouti    DJI       988,000
#           Eastern Africa            Eritrea    ERI     5,100,000
#           Eastern Africa           Ethiopia    ETH    16,700,000
# ...                                     ...    ...            ...
# Oceania   Polynesia                   Samoa    WSM    26,000,000
#           Polynesia                 Tokelau    TKL     2,000,000
#           Polynesia                   Tonga    TON    11,500,000
#           Polynesia                  Tuvalu    TUV    15,000,000
#           Polynesia       Wallis and Futuna    WLF    15,900,000
#
# [240 rows x 3 columns]

# %%
df_pop.loc['Africa','Eastern Africa']
# Out:
#                                                country code_3     Unnamed: 4
# continent sub_region
# Africa    Eastern Africa                       Burundi    BDI   128,000,000
#           Eastern Africa                       Comoros    COM       870,000
#           Eastern Africa                      Djibouti    DJI       988,000
#           Eastern Africa                       Eritrea    ERI     5,100,000
#           Eastern Africa                      Ethiopia    ETH    16,700,000
#           Eastern Africa                         Kenya    KEN    53,800,000
#           Eastern Africa                    Madagascar    MDG     4,300,000
#           Eastern Africa                        Malawi    MWI    25,800,000
#           Eastern Africa                     Mauritius    MUS     1,300,000
#           Eastern Africa                       Mayotte    MYT     4,800,000
#           Eastern Africa                    Mozambique    MOZ    51,600,000
# ...

# %%
df_2
# Out:
#     continent       sub_region            country code_3     Population
# 0        Asia    Southern Asia        Afghanistan    AFG     6,900,000
# 1      Europe  Northern Europe      Åland Islands    ALA     5,500,000
# 2      Europe  Southern Europe            Albania    ALB     3,300,000
# 3      Africa  Northern Africa            Algeria    DZA     9,500,000
# 4     Oceania        Polynesia     American Samoa    ASM        55,000
# ..        ...              ...                ...    ...            ...
# 235   Oceania        Polynesia  Wallis and Futuna    WLF    15,900,000
# 236    Africa  Northern Africa     Western Sahara    ESH       597,000
# 237      Asia     Western Asia              Yemen    YEM     5,500,000
# 238    Africa   Eastern Africa             Zambia    ZMB   213,000,000
# 239    Africa   Eastern Africa           Zimbabwe    ZWE    19,100,000
#
# [240 rows x 5 columns]

# %%
df_2.set_index('country', inplace=True)

df_2
# Out:
#                   continent       sub_region code_3     Population
# country
# Afghanistan            Asia    Southern Asia    AFG     6,900,000
# Åland Islands        Europe  Northern Europe    ALA     5,500,000
# Albania              Europe  Southern Europe    ALB     3,300,000
# Algeria              Africa  Northern Africa    DZA     9,500,000
# American Samoa      Oceania        Polynesia    ASM        55,000
# ...                     ...              ...    ...            ...
# Wallis and Futuna   Oceania        Polynesia    WLF    15,900,000
# Western Sahara       Africa  Northern Africa    ESH       597,000
# Yemen                  Asia     Western Asia    YEM     5,500,000
# Zambia               Africa   Eastern Africa    ZMB   213,000,000
# Zimbabwe             Africa   Eastern Africa    ZWE    19,100,000
#
# [240 rows x 4 columns]

# %%
df_2.loc['Wallis and Futuna']
# Out:
# continent          Oceania
# sub_region       Polynesia
# code_3                 WLF
# Population     15,900,000
# Name: Wallis and Futuna, dtype: object

# %%
df_2.reset_index(inplace=True)

# %%
df_2.set_index('continent', inplace=True)

# %%
df_2.loc['Asia']
# Out:
#                                            country          sub_region code_3  \
# continent
# Asia                                   Afghanistan       Southern Asia    AFG
# Asia                                       Armenia        Western Asia    ARM
# Asia                                    Azerbaijan        Western Asia    AZE
# Asia                                       Bahrain        Western Asia    BHR
# Asia                                    Bangladesh       Southern Asia    BGD
# Asia                                        Bhutan       Southern Asia    BTN
# Asia                             Brunei Darussalam  South-Eastern Asia    BRN
# Asia                                      Cambodia  South-Eastern Asia    KHM
# Asia                                         China        Eastern Asia    CHN
# Asia                                        Cyprus        Western Asia    CYP
# Asia                                       Georgia        Western Asia    GEO
# ...

# %%
df_2 = df_pop.sort_values(by=['continent','sub_region'])

# %%
df_2.set_index(['continent','sub_region'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21568\1388710924.py in ?()
# ----> 1 df_2.set_index(['continent','sub_region'], inplace=True)
#
# c:\Users\Stichting GeoFort\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6105                     if not found:
#    6106                         missing.append(col)
#    6107
#    6108         if missing:
# -> 6109             raise KeyError(f"None of {missing} are in the columns")
#    6110
#    6111         if inplace:
#    6112             frame = self
#
# KeyError: "None of ['continent', 'sub_region'] are in the columns"

# %%
df_world = pd.read_csv(path_2,encoding= "ISO-8859-1")

# %%
df_world = df_world.sort_values(by=['continent','sub_region'])

# %%
df_world.set_index(['continent','sub_region'], inplace=True)

# %%
df_world
# Out:
#                                     country code_3     Unnamed: 4
# continent sub_region
# Africa    Eastern Africa            Burundi    BDI   128,000,000
#           Eastern Africa            Comoros    COM       870,000
#           Eastern Africa           Djibouti    DJI       988,000
#           Eastern Africa            Eritrea    ERI     5,100,000
#           Eastern Africa           Ethiopia    ETH    16,700,000
# ...                                     ...    ...            ...
# Oceania   Polynesia                   Samoa    WSM    26,000,000
#           Polynesia                 Tokelau    TKL     2,000,000
#           Polynesia                   Tonga    TON    11,500,000
#           Polynesia                  Tuvalu    TUV    15,000,000
#           Polynesia       Wallis and Futuna    WLF    15,900,000
#
# [240 rows x 3 columns]

# %%
df_world.loc['Asia','Southern Asia']
# Out:
#                                             country code_3       Unnamed: 4
# continent sub_region
# Asia      Southern Asia                 Afghanistan    AFG       6,900,000
#           Southern Asia                  Bangladesh    BGD       2,500,000
#           Southern Asia                      Bhutan    BTN         771,000
#           Southern Asia                       India    IND   1,400,000,000
#           Southern Asia  Iran (Islamic Republic of)    IRN      84,000,000
#           Southern Asia                    Maldives    MDV         540,000
#           Southern Asia                       Nepal    NPL      44,000,000
#           Southern Asia                    Pakistan    PAK     331,000,000
#           Southern Asia                   Sri Lanka    LKA      33,000,000

# %%
df_pop = pd.read_csv(path_2, encoding= "ISO-8859-1")

# %%
df_pop.set_index(['continent'], inplace = True)

# %%
df_pop.sort_index(inplace=True)

# %%
df_pop
# Out:
#                 sub_region           country code_3    Unnamed: 4
# continent
# Africa     Northern Africa             Libya    LBY    6,900,000
# Africa      Eastern Africa         Mauritius    MUS    1,300,000
# Africa      Western Africa        Mauritania    MRT   83,200,000
# Africa      Western Africa              Mali    MLI   30,000,000
# Africa      Eastern Africa            Malawi    MWI   25,800,000
# ...                    ...               ...    ...           ...
# Oceania         Micronesia              Guam    GUM    2,800,000
# Oceania          Polynesia    American Samoa    ASM       55,000
# Oceania          Polynesia           Tokelau    TKL    2,000,000
# Oceania          Polynesia              Niue    NIU    2,400,000
# Oceania          Polynesia  French Polynesia    PYF   40,000,000
#
# [240 rows x 4 columns]

# %%
df_pop.reset_index(inplace=True)

# %%
df_pop.set_index(['continent','sub_region'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 df_pop.set_index(['continent','sub_region'], inplace=True).sort_index(level='continent')
#
# AttributeError: 'NoneType' object has no attribute 'sort_index'

# %%
df_pop.sort_index(level='continent', inplace=True)

# %%
df_pop
# Out:
#                                    country code_3     Unnamed: 4
# continent sub_region
# Africa    Eastern Africa         Mauritius    MUS     1,300,000
#           Eastern Africa            Malawi    MWI    25,800,000
#           Eastern Africa        Madagascar    MDG     4,300,000
#           Eastern Africa            Zambia    ZMB   213,000,000
#           Eastern Africa             Kenya    KEN    53,800,000
# ...                                    ...    ...            ...
# Oceania   Polynesia               Pitcairn    PCN    50,000,000
#           Polynesia         American Samoa    ASM        55,000
#           Polynesia                Tokelau    TKL     2,000,000
#           Polynesia                   Niue    NIU     2,400,000
#           Polynesia       French Polynesia    PYF    40,000,000
#
# [240 rows x 3 columns]

# %%
df_pop.swaplevel('continent','sub_region')
# Out:
#                                    country code_3     Unnamed: 4
# sub_region     continent
# Eastern Africa Africa            Mauritius    MUS     1,300,000
#                Africa               Malawi    MWI    25,800,000
#                Africa           Madagascar    MDG     4,300,000
#                Africa               Zambia    ZMB   213,000,000
#                Africa                Kenya    KEN    53,800,000
# ...                                    ...    ...            ...
# Polynesia      Oceania            Pitcairn    PCN    50,000,000
#                Oceania      American Samoa    ASM        55,000
#                Oceania             Tokelau    TKL     2,000,000
#                Oceania                Niue    NIU     2,400,000
#                Oceania    French Polynesia    PYF    40,000,000
#
# [240 rows x 3 columns]

# %%
path_tech = r"C:\Users\Stichting GeoFort\Downloads\tech_price.xlsx"

# %%
tech = pd.read_excel(path_tech, header=[0,1], index_col=[0,1])

# %%
tech
# Out:
#                    USD                 EUR
# company           open high low close open high low close
# 2023-01-01 Apple    89   26  68    69   37   56  11    25
#            Google   66   71  26    83   96   68  91    11
#            Amazon   12   43  97    75   25   25  90    43
# 2023-01-02 Apple    54   49  77    49   68   44  85    68
#            Google   84   92  55    90   51   50  59    68
#            Amazon   41   86  13    19   41   36  50    26
# 2023-01-03 Apple    67   47  46    70   41   62  72    49
#            Google   60   70  54    71   78   47  12    57
#            Amazon   71   15  47    53   86   44  68    33
# 2023-01-04 Apple    56   50  54    83   59   36  45    19
#            Google   36   77  27    94   62   13  66    90
#            Amazon   64   97  64    56   48   57  45    50
# 2023-01-05 Apple    34   45  60    84   24   49  63    54
#            Google   69   92  14    63   21   85  80    87
# ...

# %%
tech.stack()
# Out:
# C:\Users\Stichting GeoFort\AppData\Local\Temp\ipykernel_21568\1623489563.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   tech.stack()
#                            USD  EUR
#                   company
# 2023-01-01 Apple  close     69   25
#                   high      26   56
#                   low       68   11
#                   open      89   37
#            Google close     83   11
#                   high      71   68
#                   low       26   91
#                   open      66   96
#            Amazon close     75   43
#                   high      43   25
#                   low       97   90
#                   open      12   25
# 2023-01-02 Apple  close     49   68
#                   high      49   44
#                   low       77   85
# ...

# %%
tech.unstack()
# Out:
#               USD                                                              \
# company      open                high                 low               close
#            Amazon Apple Google Amazon Apple Google Amazon Apple Google Amazon
# 2023-01-01     12    89     66     43    26     71     97    68     26     75
# 2023-01-02     41    54     84     86    49     92     13    77     55     19
# 2023-01-03     71    67     60     15    47     70     47    46     54     53
# 2023-01-04     64    56     36     97    50     77     64    54     27     56
# 2023-01-05     63    34     69     75    45     92     27    60     14     43
#
#             ...    EUR                                                       \
# company     ...   open   high                 low               close
#             ... Google Amazon Apple Google Amazon Apple Google Amazon Apple
# 2023-01-01  ...     96     25    56     68     90    11     91     43    25
# ...

# %%
tech
# Out:
#                    USD                 EUR
# company           open high low close open high low close
# 2023-01-01 Apple    89   26  68    69   37   56  11    25
#            Google   66   71  26    83   96   68  91    11
#            Amazon   12   43  97    75   25   25  90    43
# 2023-01-02 Apple    54   49  77    49   68   44  85    68
#            Google   84   92  55    90   51   50  59    68
#            Amazon   41   86  13    19   41   36  50    26
# 2023-01-03 Apple    67   47  46    70   41   62  72    49
#            Google   60   70  54    71   78   47  12    57
#            Amazon   71   15  47    53   86   44  68    33
# 2023-01-04 Apple    56   50  54    83   59   36  45    19
#            Google   36   77  27    94   62   13  66    90
#            Amazon   64   97  64    56   48   57  45    50
# 2023-01-05 Apple    34   45  60    84   24   49  63    54
#            Google   69   92  14    63   21   85  80    87
# ...

# %%
df_pop = pd.read_csv(path_2, encoding= "ISO-8859-1")

# %%
df_pop
# Out:
#     continent       sub_region            country code_3     Unnamed: 4
# 0        Asia    Southern Asia        Afghanistan    AFG     6,900,000
# 1      Europe  Northern Europe      Åland Islands    ALA     5,500,000
# 2      Europe  Southern Europe            Albania    ALB     3,300,000
# 3      Africa  Northern Africa            Algeria    DZA     9,500,000
# 4     Oceania        Polynesia     American Samoa    ASM        55,000
# ..        ...              ...                ...    ...            ...
# 235   Oceania        Polynesia  Wallis and Futuna    WLF    15,900,000
# 236    Africa  Northern Africa     Western Sahara    ESH       597,000
# 237      Asia     Western Asia              Yemen    YEM     5,500,000
# 238    Africa   Eastern Africa             Zambia    ZMB   213,000,000
# 239    Africa   Eastern Africa           Zimbabwe    ZWE    19,100,000
#
# [240 rows x 5 columns]

# %%
c
# Out:
# continent              Africa Americas         Asia       Europe   Oceania
# country
# Afghanistan               NaN      NaN   6,900,000           NaN       NaN
# Albania                   NaN      NaN          NaN   3,300,000        NaN
# Algeria            9,500,000       NaN          NaN          NaN       NaN
# American Samoa            NaN      NaN          NaN          NaN   55,000
# Andorra                   NaN      NaN          NaN      77,000        NaN
# ...                       ...      ...          ...          ...       ...
# Western Sahara       597,000       NaN          NaN          NaN       NaN
# Yemen                     NaN      NaN   5,500,000           NaN       NaN
# Zambia           213,000,000       NaN          NaN          NaN       NaN
# Zimbabwe          19,100,000       NaN          NaN          NaN       NaN
# Åland Islands             NaN      NaN          NaN   5,500,000        NaN
#
# [240 rows x 5 columns]

# %%
df_pop.pivot(index='country', columns=['continent', 'sub_region'], values='Unnamed: 4')
# Out:
# continent               Asia          Europe                          Africa  \
# sub_region     Southern Asia Northern Europe Southern Europe Northern Africa
# country
# Afghanistan       6,900,000              NaN             NaN             NaN
# Albania                  NaN             NaN      3,300,000              NaN
# Algeria                  NaN             NaN             NaN      9,500,000
# American Samoa           NaN             NaN             NaN             NaN
# Andorra                  NaN             NaN         77,000              NaN
# ...                      ...             ...             ...             ...
# Western Sahara           NaN             NaN             NaN        597,000
# Yemen                    NaN             NaN             NaN             NaN
# Zambia                   NaN             NaN             NaN             NaN
# Zimbabwe                 NaN             NaN             NaN             NaN
# ...
