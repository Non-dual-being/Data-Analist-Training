# %%
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
import numpy as np

# %%
path = r"C:\Users\Stichting GeoFort\Downloads\real_estate.csv"
df = pd.read_csv(path)
df
# Out:
#          status  bed  bath  acre_lot        city          state  zip_code  \
# 0      for_sale  3.0   2.0      0.12    Adjuntas    Puerto Rico     601.0
# 1      for_sale  4.0   2.0      0.08    Adjuntas    Puerto Rico     601.0
# 2      for_sale  2.0   1.0      0.15  Juana Diaz    Puerto Rico     795.0
# 3      for_sale  4.0   2.0      0.10       Ponce    Puerto Rico     731.0
# 4      for_sale  6.0   2.0      0.05    Mayaguez    Puerto Rico     680.0
# ...         ...  ...   ...       ...         ...            ...       ...
# 99995  for_sale  3.0   3.0       NaN      Hudson  Massachusetts    1749.0
# 99996  for_sale  2.0   1.0      0.34      Auburn  Massachusetts    1501.0
# 99997  for_sale  3.0   2.0      1.01  Shrewsbury  Massachusetts    1545.0
# 99998  for_sale  3.0   2.0      0.12   Worcester  Massachusetts    1604.0
# 99999  for_sale  3.0   3.0     21.67     Grafton  Massachusetts    1536.0
#
#        house_size prev_sold_date     price
# ...

# %%
df_filtered = df[df['state'].str.contains('New|Rico', case=False, na=False)]

"""
case = False wil zeggen niet hoofdletter gevoelig
Na false wil zeggen dat ontbrekende waarden niet worden opgenomen
"""
# Out:
# '\ncase = False wil zeggen niet hoofdletter gevoelig\nNa false wil zeggen dat ontbrekende waarden niet worden opgenomen\n'

# %%
sns.barplot(data=df_filtered, x='state', y='price', hue='state', legend=False, estimator='min')
plt.plot()

"""
estimator gaat price automatisch aggregeren op basis van state
"""
# Out:
# []

# %%
sns.set_style('darkgrid')

# %%
sns.barplot(data=df_filtered, x='state', y='price', hue='state', legend=False, estimator='min')
plt.title('lowest prices')
plt.plot()
# Out:
# []

# %%
sns.set_palette() #customize the color and stuff
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sns.set_palette() #customize the color and stuff
#
# TypeError: set_palette() missing 1 required positional argument: 'palette'

# %%
sns.regplot(data = df, x = 'house_size', y='price')
# Out:
# <Axes: xlabel='house_size', ylabel='price'>

# %%
sns.set_style('darkgrid')

# %%
drop_idx = df['house_size'].idxmax()

df = df.drop(drop_idx,axis=0) 

df
# Out:
#          status  bed  bath  acre_lot        city          state  zip_code  \
# 0      for_sale  3.0   2.0      0.12    Adjuntas    Puerto Rico     601.0
# 1      for_sale  4.0   2.0      0.08    Adjuntas    Puerto Rico     601.0
# 2      for_sale  2.0   1.0      0.15  Juana Diaz    Puerto Rico     795.0
# 3      for_sale  4.0   2.0      0.10       Ponce    Puerto Rico     731.0
# 4      for_sale  6.0   2.0      0.05    Mayaguez    Puerto Rico     680.0
# ...         ...  ...   ...       ...         ...            ...       ...
# 99995  for_sale  3.0   3.0       NaN      Hudson  Massachusetts    1749.0
# 99996  for_sale  2.0   1.0      0.34      Auburn  Massachusetts    1501.0
# 99997  for_sale  3.0   2.0      1.01  Shrewsbury  Massachusetts    1545.0
# 99998  for_sale  3.0   2.0      0.12   Worcester  Massachusetts    1604.0
# 99999  for_sale  3.0   3.0     21.67     Grafton  Massachusetts    1536.0
#
#        house_size prev_sold_date     price
# ...

# %%
df_filtered_2 = df[df['house_size'] <= 10000]

# %%
sns.regplot(data = df_filtered_2, x = 'house_size', y='price')
# Out:
# <Axes: xlabel='house_size', ylabel='price'>

# %%
sns.regplot(data = df_filtered_2, x = 'house_size', y='price', line_kws={'color': 'red'})
# Out:
# <Axes: xlabel='house_size', ylabel='price'>

# %%
sns.regplot(data = df_filtered_2, x = 'house_size', y='price', line_kws={'color': 'red'})
plt.ticklabel_format(style='plain', axis = 'y')
plt.show()

# %%
iris = sns.load_dataset('iris')

# %%
sns.pairplot(iris,hue = 'species' )

# %%
sns.stripplot(data = iris, x = 'species', y = 'sepal_length', hue = 'species')
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.swarmplot(data = iris, x = 'species', y = 'sepal_length', hue = 'species')
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.violinplot(data = iris, x = 'species', y = 'sepal_length', hue = 'species')
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
path = r"C:\Users\Stichting GeoFort\Downloads\smoking.csv"
smoking = pd.read_csv(path)
smoking
# Out:
#       Unnamed: 0  gender  age marital_status highest_qualification  \
# 0              1    Male   38       Divorced      No Qualification
# 1              2  Female   42         Single      No Qualification
# 2              3    Male   40        Married                Degree
# 3              4  Female   40        Married                Degree
# 4              5  Female   39        Married          GCSE/O Level
# ...          ...     ...  ...            ...                   ...
# 1686        1687    Male   22         Single      No Qualification
# 1687        1688  Female   49       Divorced      Other/Sub Degree
# 1688        1689    Male   45        Married      Other/Sub Degree
# 1689        1690  Female   51        Married      No Qualification
# 1690        1691    Male   31        Married                Degree
#
#      nationality ethnicity      gross_income     region smoke  amt_weekends  \
# 0        British     White    2,600 to 5,200  The North    No           NaN
# ...

# %%
smoking = smoking[smoking['smoking'] == 'Yes']

# %%
female_smokers = smoking[smoking['gender'] == 'Female']
male_smokers = smoking[smoking['gender'] == 'Male']

# %%
fig, axs = plt.subplots(1,2)

sns.histplot(female_smokers['age'], bins = 25, ax= axs[0])

axs[0].set_title('Age Distribution - Female Smokers')
axs[1].set_title('Age Distribution - Male Smokers')

sns.histplot(male_smokers['age'], bins = 25, ax= axs[1])
plt.tight_layout()
plt.show()

# %%
df_corr.corr(numeric_only=True)
# Out:
#                  bed      bath  acre_lot  house_size     price
# bed         1.000000  0.715538  0.000134    0.620775  0.199936
# bath        0.715538  1.000000  0.005749    0.742961  0.383334
# acre_lot    0.000134  0.005749  1.000000    0.005731  0.012853
# house_size  0.620775  0.742961  0.005731    1.000000  0.429944
# price       0.199936  0.383334  0.012853    0.429944  1.000000

# %%
df_corr = df.drop(columns='zip_code')

# %%
correlation = df_corr.corr(numeric_only=True)

# %%
sns.heatmap(correlation, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
pearson = df_corr.corr(numeric_only=True, method='pearson')

# %%
spearman, kendall = df_corr.corr(numeric_only=True, method='spearman'), df_corr.corr(numeric_only=True, method='kendall')

# %%
kendall
# Out:
#                  bed      bath  acre_lot  house_size     price
# bed         1.000000  0.498766 -0.013624    0.524948  0.202582
# bath        0.498766  1.000000  0.177484    0.632020  0.448990
# acre_lot   -0.013624  0.177484  1.000000    0.196220  0.102113
# house_size  0.524948  0.632020  0.196220    1.000000  0.479512
# price       0.202582  0.448990  0.102113    0.479512  1.000000

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

sns.heatmap(pearson, annot=True, cmap='coolwarm', ax=axs[0], cbar=False)
sns.heatmap(spearman, annot=True, cmap='coolwarm', ax=axs[1], cbar=False)
sns.heatmap(kendall, annot=True, cmap='coolwarm', ax=axs[2])

# Zet de titels
axs[0].set_title('Pearson heatmap')
axs[1].set_title('Spearman heatmap')
axs[2].set_title('Kendall heatmap')

# Verwijder de y-as bij de eerste twee plots
axs[2].set_yticks([])  # Verwijdert de y-as ticks
axs[2].set_ylabel('')   # Verwijdert de y-as labels

axs[1].set_yticks([])  # Verwijdert de y-as ticks
axs[1].set_ylabel('')   # Verwijdert de y-as labels


axs[2].set_xticklabels(axs[2].get_xticklabels(), rotation=0)
sns.set_style('darkgrid')

plt.tight_layout()
plt.show()
