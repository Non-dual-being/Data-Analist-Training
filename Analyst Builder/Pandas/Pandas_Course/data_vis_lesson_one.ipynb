# %%
import pandas as pd

# %%
path = r"C:\Users\Stichting GeoFort\Downloads\all_stocks_5yr.csv"

df = pd.read_csv(path)

# %%
df
# Out:
#              date   open   high    low  close    volume Name
# 0        2/8/2017  15.07  15.12  14.63  14.75   8407500  AAL
# 1       2/11/2017  14.89  15.01  14.26  14.46   8882000  AAL
# 2       2/12/2017  14.45  14.51  14.10  14.27   8126000  AAL
# 3       2/13/2017  14.30  14.94  14.25  14.66  10259500  AAL
# 4       2/14/2017  14.94  14.96  13.16  13.99  31879900  AAL
# ...           ...    ...    ...    ...    ...       ...  ...
# 619035   2/1/2022  76.84  78.27  76.69  77.82   2982259  ZTS
# 619036   2/2/2022  77.53  78.12  76.73  76.78   2595187  ZTS
# 619037   2/5/2022  76.64  76.92  73.18  73.83   2962031  ZTS
# 619038   2/6/2022  72.74  74.56  72.13  73.27   4924323  ZTS
# 619039   2/7/2022  72.70  75.00  72.69  73.86   4534912  ZTS
#
# [619040 rows x 7 columns]

# %%
df.plot(x = 'date', y = 'close')
# Out:
# <Axes: xlabel='date'>

# %%
df_2017 = df[df['date'].str.contains("2017")]

# %%
import matplotlib.pyplot as plt

# %%
df_2017.plot(x='date', y='close')
plt.show()

# %%
company_AAL = df[df['Name'] == 'AAL']

# %%
company_AAL.plot(x = 'date', y = 'close')
# Out:
# <Axes: xlabel='date'>

# %%
df.plot(x='Name', y='volume', kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Stichting GeoFort\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ...

# %%
company_df_grouped = df.groupby('Name')['volume'].sum().reset_index()

# %%
company_df_grouped
# Out:
#      Name       volume
# 0       A   2943590983
# 1     AAL  11822414547
# 2     AAP   1357256410
# 3    AAPL  68046305767
# 4    ABBV   9909189476
# ..    ...          ...
# 500   XYL   1489574691
# 501   YUM   4040170774
# 502   ZBH   1633103868
# 503  ZION   3300062992
# 504   ZTS   4635485010
#
# [505 rows x 2 columns]

# %%
company_df_grouped_filtered = company_df_grouped[company_df_grouped['Name'].str.contains('AA')]

# %%
company_df_grouped_filtered.plot(x='Name', y='volume', kind='bar')
# Out:
# <Axes: xlabel='Name'>

# %%
company_AAL.plot(x = 'open', y = 'close', kind ='scatter')
# Out:
# <Axes: xlabel='open', ylabel='close'>

# %%
company_AAL['high'].plot.hist(bins= 10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
company_AAL['high'].plot.hist(bins= 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
pie_df = df[df['Name'].isin(['AAL','GOOG','AAPL'])]

# %%
pie_df_grouped = pie_df.groupby('Name')['volume'].sum().reset_index()

# %%
pie_df_grouped
# Out:
#    Name       volume
# 0   AAL  11822414547
# 1  AAPL  68046305767
# 2  GOOG   1763203456

# %%
pie_df_grouped.plot(y='volume', kind='pie', labels=pie_df_grouped['Name'],legend=True, figsize=(6,6))
# Out:
# <Axes: ylabel='volume'>

# %%
company_AAL[['low','close','open','high']].plot(kind='box')
#the boxes are 50 procent of the date, the greenline is the median
# Out:
# <Axes: >

# %%
company_AAL[['volume']].plot(kind='box')
# Out:
# <Axes: >
