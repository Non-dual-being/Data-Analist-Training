# %%
import pandas as pd

# %%
data1 = {
    'employee_id': [1, 2, 3, 4, 5, 6, 7, 8],
    'name': ['Michael Scott', 'Jim Halpert', 'Pam Beesly', 'Dwight Schrute', 'Angela Martin', 'Kevin Malone', 'Oscar Martinez', 'Stanley Hudson'],
    'job_title': ['Regional Manager', 'Sales Representative', 'Receptionist', 'Assistant to the Regional Manager', 'Head of Accounting', 'Accountant', 'Accountant', 'Sales Representative'],
    'salary': [100000, 60000, 55000, 65000, 60000, 55000, 55000, 60000]
}

df1 = pd.DataFrame(data1)

data2 = {
    'employee_id': [1, 2, 3, 5, 6, 7, 8, 9],
    'name': ['Michael Scott', 'Jim Halpert', 'Pam Beesly', 'Angela Martin', 'Kevin Malone', 'Oscar Martinez', 'Stanley Hudson', 'Phyllis Vance'],
    'department': ['Management', 'Sales', 'Reception', 'Accounting', 'Accounting', 'Accounting', 'Sales', 'Sales']
}

df2 = pd.DataFrame(data2)

# %%
df1
# Out:
#    employee_id            name                          job_title  salary
# 0            1   Michael Scott                   Regional Manager  100000
# 1            2     Jim Halpert               Sales Representative   60000
# 2            3      Pam Beesly                       Receptionist   55000
# 3            4  Dwight Schrute  Assistant to the Regional Manager   65000
# 4            5   Angela Martin                 Head of Accounting   60000
# 5            6    Kevin Malone                         Accountant   55000
# 6            7  Oscar Martinez                         Accountant   55000
# 7            8  Stanley Hudson               Sales Representative   60000

# %%
df2
# Out:
#    employee_id            name  department
# 0            1   Michael Scott  Management
# 1            2     Jim Halpert       Sales
# 2            3      Pam Beesly   Reception
# 3            5   Angela Martin  Accounting
# 4            6    Kevin Malone  Accounting
# 5            7  Oscar Martinez  Accounting
# 6            8  Stanley Hudson       Sales
# 7            9   Phyllis Vance       Sales

# %%
df1.merge(df2, how="inner", on=["employee_id","name"])
# Out:
#    employee_id            name             job_title  salary  department
# 0            1   Michael Scott      Regional Manager  100000  Management
# 1            2     Jim Halpert  Sales Representative   60000       Sales
# 2            3      Pam Beesly          Receptionist   55000   Reception
# 3            5   Angela Martin    Head of Accounting   60000  Accounting
# 4            6    Kevin Malone            Accountant   55000  Accounting
# 5            7  Oscar Martinez            Accountant   55000  Accounting
# 6            8  Stanley Hudson  Sales Representative   60000       Sales

# %%
df1.join(df2, how="inner", lsuffix='_df1', rsuffix='_df2' ) #join works on index , so this is dirty date
# Out:
#    employee_id_df1        name_df1                          job_title  salary  \
# 0                1   Michael Scott                   Regional Manager  100000
# 1                2     Jim Halpert               Sales Representative   60000
# 2                3      Pam Beesly                       Receptionist   55000
# 3                4  Dwight Schrute  Assistant to the Regional Manager   65000
# 4                5   Angela Martin                 Head of Accounting   60000
# 5                6    Kevin Malone                         Accountant   55000
# 6                7  Oscar Martinez                         Accountant   55000
# 7                8  Stanley Hudson               Sales Representative   60000
#
#    employee_id_df2        name_df2  department
# 0                1   Michael Scott  Management
# 1                2     Jim Halpert       Sales
# 2                3      Pam Beesly   Reception
# 3                5   Angela Martin  Accounting
# 4                6    Kevin Malone  Accounting
# 5                7  Oscar Martinez  Accounting
# 6                8  Stanley Hudson       Sales
# 7                9   Phyllis Vance       Sales

# %%
df1 = df1.reset_index()
df2 = df2.reset_index()

# %%
df1.set_index('employee_id', inplace=True)
df2.set_index('employee_id', inplace=True)

# %%
df1.join(df2, how="inner", lsuffix='_df1', rsuffix='_df2' ) #works now
# Out:
#                    name_df1             job_title  salary        name_df2  \
# employee_id
# 1             Michael Scott      Regional Manager  100000   Michael Scott
# 2               Jim Halpert  Sales Representative   60000     Jim Halpert
# 3                Pam Beesly          Receptionist   55000      Pam Beesly
# 5             Angela Martin    Head of Accounting   60000   Angela Martin
# 6              Kevin Malone            Accountant   55000    Kevin Malone
# 7            Oscar Martinez            Accountant   55000  Oscar Martinez
# 8            Stanley Hudson  Sales Representative   60000  Stanley Hudson
#
#              department
# employee_id
# 1            Management
# 2                 Sales
# 3             Reception
# 5            Accounting
# 6            Accounting
# 7            Accounting
# 8                 Sales

# %%
data1 = {
    'employee_id': [1, 2, 3, 4, 5, 6, 7, 8],
    'name': ['Michael Scott', 'Jim Halpert', 'Pam Beesly', 'Dwight Schrute', 'Angela Martin', 'Kevin Malone', 'Oscar Martinez', 'Stanley Hudson'],
    'job_title': ['Regional Manager', 'Sales Representative', 'Receptionist', 'Assistant to the Regional Manager', 'Head of Accounting', 'Accountant', 'Accountant', 'Sales Representative'],
    'salary': [100000, 60000, 55000, 65000, 60000, 55000, 55000, 60000]
}

df1 = pd.DataFrame(data1)

data2 = {
    'employee_id': [1, 2, 3, 5, 6, 7, 8, 9],
    'name': ['Michael Scott', 'Jim Halpert', 'Pam Beesly', 'Angela Martin', 'Kevin Malone', 'Oscar Martinez', 'Stanley Hudson', 'Phyllis Vance'],
    'department': ['Management', 'Sales', 'Reception', 'Accounting', 'Accounting', 'Accounting', 'Sales', 'Sales']
}

df2 = pd.DataFrame(data2)

# %%
pd.merge(df1, df2[['employee_id','department']], on='employee_id', how='inner')
# Out:
#    employee_id            name             job_title  salary  department
# 0            1   Michael Scott      Regional Manager  100000  Management
# 1            2     Jim Halpert  Sales Representative   60000       Sales
# 2            3      Pam Beesly          Receptionist   55000   Reception
# 3            5   Angela Martin    Head of Accounting   60000  Accounting
# 4            6    Kevin Malone            Accountant   55000  Accounting
# 5            7  Oscar Martinez            Accountant   55000  Accounting
# 6            8  Stanley Hudson  Sales Representative   60000       Sales

# %%
pd.merge(df1, df2[['employee_id','department','name']], on='employee_id', how='inner', suffixes=('_left','_right'))
# Out:
#    employee_id       name_left             job_title  salary  department  \
# 0            1   Michael Scott      Regional Manager  100000  Management
# 1            2     Jim Halpert  Sales Representative   60000       Sales
# 2            3      Pam Beesly          Receptionist   55000   Reception
# 3            5   Angela Martin    Head of Accounting   60000  Accounting
# 4            6    Kevin Malone            Accountant   55000  Accounting
# 5            7  Oscar Martinez            Accountant   55000  Accounting
# 6            8  Stanley Hudson  Sales Representative   60000       Sales
#
#        name_right
# 0   Michael Scott
# 1     Jim Halpert
# 2      Pam Beesly
# 3   Angela Martin
# 4    Kevin Malone
# 5  Oscar Martinez
# 6  Stanley Hudson

# %%
pd.merge(df1, df2[['employee_id','department','name']], on='employee_id', how='inner', suffixes=('_left','_right'), indicator=True)
# Out:
#    employee_id       name_left             job_title  salary  department  \
# 0            1   Michael Scott      Regional Manager  100000  Management
# 1            2     Jim Halpert  Sales Representative   60000       Sales
# 2            3      Pam Beesly          Receptionist   55000   Reception
# 3            5   Angela Martin    Head of Accounting   60000  Accounting
# 4            6    Kevin Malone            Accountant   55000  Accounting
# 5            7  Oscar Martinez            Accountant   55000  Accounting
# 6            8  Stanley Hudson  Sales Representative   60000       Sales
#
#        name_right _merge
# 0   Michael Scott   both
# 1     Jim Halpert   both
# 2      Pam Beesly   both
# 3   Angela Martin   both
# 4    Kevin Malone   both
# 5  Oscar Martinez   both
# 6  Stanley Hudson   both

# %%
pd.merge(df1, df2[['employee_id','department','name']], on='employee_id', how='outer', suffixes=('_left','_right'), indicator=True)
# Out:
#    employee_id       name_left                          job_title    salary  \
# 0            1   Michael Scott                   Regional Manager  100000.0
# 1            2     Jim Halpert               Sales Representative   60000.0
# 2            3      Pam Beesly                       Receptionist   55000.0
# 3            4  Dwight Schrute  Assistant to the Regional Manager   65000.0
# 4            5   Angela Martin                 Head of Accounting   60000.0
# 5            6    Kevin Malone                         Accountant   55000.0
# 6            7  Oscar Martinez                         Accountant   55000.0
# 7            8  Stanley Hudson               Sales Representative   60000.0
# 8            9             NaN                                NaN       NaN
#
#    department      name_right      _merge
# 0  Management   Michael Scott        both
# 1       Sales     Jim Halpert        both
# 2   Reception      Pam Beesly        both
# 3         NaN             NaN   left_only
# 4  Accounting   Angela Martin        both
# 5  Accounting    Kevin Malone        both
# 6  Accounting  Oscar Martinez        both
# 7       Sales  Stanley Hudson        both
# 8       Sales   Phyllis Vance  right_only

# %%
import pandas as pd

data1 = {
    'employee_id': [1, 2, 3, 4, 5, 6, 7, 8],
    'name': ['Michael Scott', 'Jim Halpert', 'Pam Beesly', 'Dwight Schrute', 'Angela Martin', 'Kevin Malone', 'Oscar Martinez', 'Stanley Hudson'],
    'job_title': ['Regional Manager', 'Sales Representative', 'Receptionist', 'Assistant to the Regional Manager', 'Head of Accounting', 'Accountant', 'Accountant', 'Sales Representative'],
    'salary': [100000, 60000, 55000, 65000, 60000, 55000, 55000, 60000]
}

demographics = pd.DataFrame(data1)

data2 = {
    'employee_id': [1, 2, 3, 5, 6, 7, 8, 9],
    'name': ['Michael Scott', 'Jim Halpert', 'Pam Beesly', 'Angela Martin', 'Kevin Malone', 'Oscar Martinez', 'Stanley Hudson', 'Phyllis Vance'],
    'department_id': [1, 2, 3, 4, 4, 4, 2, 2]
}

name_dep = pd.DataFrame(data2)


data3 = {
    'employee_id': [1, 2, 3, 4, 5, 6, 7, 8, 9],
    'manager_id': [None, 1, 1, 1, 1, 4, 4, 1, 1]
}


manager = pd.DataFrame(data3)


data4 = {
    'department_id': [1, 2, 3, 4],
    'department': ['Management', 'Sales', 'Reception', 'Accounting']
}


department = pd.DataFrame(data4)

# %%
manager
# Out:
#    employee_id  manager_id
# 0            1         NaN
# 1            2         1.0
# 2            3         1.0
# 3            4         1.0
# 4            5         1.0
# 5            6         4.0
# 6            7         4.0
# 7            8         1.0
# 8            9         1.0

# %%
department
# Out:
#    department_id  department
# 0              1  Management
# 1              2       Sales
# 2              3   Reception
# 3              4  Accounting

# %%
manager['manager_id']= manager['manager_id'].astype('Int64')

# %%
import numpy as np
manager.loc[0, 'manager_id'] = np.nan

# %%
manager
# Out:
#    employee_id  manager_id
# 0            1        <NA>
# 1            2           1
# 2            3           1
# 3            4           1
# 4            5           1
# 5            6           4
# 6            7           4
# 7            8           1
# 8            9           1

# %%
department
# Out:
#    department_id  department
# 0              1  Management
# 1              2       Sales
# 2              3   Reception
# 3              4  Accounting

# %%
demographics
# Out:
#    employee_id            name                          job_title  salary
# 0            1   Michael Scott                   Regional Manager  100000
# 1            2     Jim Halpert               Sales Representative   60000
# 2            3      Pam Beesly                       Receptionist   55000
# 3            4  Dwight Schrute  Assistant to the Regional Manager   65000
# 4            5   Angela Martin                 Head of Accounting   60000
# 5            6    Kevin Malone                         Accountant   55000
# 6            7  Oscar Martinez                         Accountant   55000
# 7            8  Stanley Hudson               Sales Representative   60000

# %%
merged = pd.merge(demographics, name_dep, on=['employee_id','name'], how='inner').merge(department, on =['department_id'], how='inner')

# %%
merged_2 = merged.merge(manager, on='employee_id', how='inner')

# %%
merged_2
# Out:
#    employee_id            name             job_title  salary  department_id  \
# 0            1   Michael Scott      Regional Manager  100000              1
# 1            2     Jim Halpert  Sales Representative   60000              2
# 2            3      Pam Beesly          Receptionist   55000              3
# 3            5   Angela Martin    Head of Accounting   60000              4
# 4            6    Kevin Malone            Accountant   55000              4
# 5            7  Oscar Martinez            Accountant   55000              4
# 6            8  Stanley Hudson  Sales Representative   60000              2
#
#    department  manager_id
# 0  Management        <NA>
# 1       Sales           1
# 2   Reception           1
# 3  Accounting           1
# 4  Accounting           4
# 5  Accounting           4
# 6       Sales           1

# %%
import pandas as pd

data1 = {
    'employee_id': [1, 2, 3, 4, 5, 6, 7, 8],
    'name': ['Michael Scott', 'Jim Halpert', 'Pam Beesly', 'Dwight Schrute', 'Angela Martin', 'Kevin Malone', 'Oscar Martinez', 'Stanley Hudson'],
    'job_title': ['Regional Manager', 'Sales Representative', 'Receptionist', 'Assistant to the Regional Manager', 'Head of Accounting', 'Accountant', 'Accountant', 'Sales Representative'],
    'salary': [100000, 60000, 55000, 65000, 60000, 55000, 55000, 60000]
}

df1 = pd.DataFrame(data1)

data2 = {
    'employee_id': [1, 2, 3, 5, 6, 7, 8, 9],
    'name': ['Michael Scott', 'Jim Halpert', 'Pam Beesly', 'Angela Martin', 'Kevin Malone', 'Oscar Martinez', 'Stanley Hudson', 'Phyllis Vance'],
    'department': ['Management', 'Sales', 'Reception', 'Accounting', 'Accounting', 'Accounting', 'Sales', 'Sales']
}

df2 = pd.DataFrame(data2)

# %%
df1
# Out:
#    employee_id            name                          job_title  salary
# 0            1   Michael Scott                   Regional Manager  100000
# 1            2     Jim Halpert               Sales Representative   60000
# 2            3      Pam Beesly                       Receptionist   55000
# 3            4  Dwight Schrute  Assistant to the Regional Manager   65000
# 4            5   Angela Martin                 Head of Accounting   60000
# 5            6    Kevin Malone                         Accountant   55000
# 6            7  Oscar Martinez                         Accountant   55000
# 7            8  Stanley Hudson               Sales Representative   60000

# %%
df2
# Out:
#    employee_id            name  department
# 0            1   Michael Scott  Management
# 1            2     Jim Halpert       Sales
# 2            3      Pam Beesly   Reception
# 3            5   Angela Martin  Accounting
# 4            6    Kevin Malone  Accounting
# 5            7  Oscar Martinez  Accounting
# 6            8  Stanley Hudson       Sales
# 7            9   Phyllis Vance       Sales

# %%
pd.concat([df1,df2])
# Out:
#    employee_id            name                          job_title    salary  \
# 0            1   Michael Scott                   Regional Manager  100000.0
# 1            2     Jim Halpert               Sales Representative   60000.0
# 2            3      Pam Beesly                       Receptionist   55000.0
# 3            4  Dwight Schrute  Assistant to the Regional Manager   65000.0
# 4            5   Angela Martin                 Head of Accounting   60000.0
# 5            6    Kevin Malone                         Accountant   55000.0
# 6            7  Oscar Martinez                         Accountant   55000.0
# 7            8  Stanley Hudson               Sales Representative   60000.0
# 0            1   Michael Scott                                NaN       NaN
# 1            2     Jim Halpert                                NaN       NaN
# 2            3      Pam Beesly                                NaN       NaN
# 3            5   Angela Martin                                NaN       NaN
# 4            6    Kevin Malone                                NaN       NaN
# 5            7  Oscar Martinez                                NaN       NaN
# 6            8  Stanley Hudson                                NaN       NaN
# 7            9   Phyllis Vance                                NaN       NaN
#
#    department
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 0  Management
# 1       Sales
# 2   Reception
# 3  Accounting
# 4  Accounting
# 5  Accounting
# 6       Sales
# 7       Sales

# %%
pd.concat([df1,df2], axis=1)
# Out:
#    employee_id            name                          job_title  salary  \
# 0            1   Michael Scott                   Regional Manager  100000
# 1            2     Jim Halpert               Sales Representative   60000
# 2            3      Pam Beesly                       Receptionist   55000
# 3            4  Dwight Schrute  Assistant to the Regional Manager   65000
# 4            5   Angela Martin                 Head of Accounting   60000
# 5            6    Kevin Malone                         Accountant   55000
# 6            7  Oscar Martinez                         Accountant   55000
# 7            8  Stanley Hudson               Sales Representative   60000
#
#    employee_id            name  department
# 0            1   Michael Scott  Management
# 1            2     Jim Halpert       Sales
# 2            3      Pam Beesly   Reception
# 3            5   Angela Martin  Accounting
# 4            6    Kevin Malone  Accounting
# 5            7  Oscar Martinez  Accounting
# 6            8  Stanley Hudson       Sales
# 7            9   Phyllis Vance       Sales

# %%
pd.concat([df1.set_index('employee_id'),df2.set_index('employee_id')], axis=1, join='inner')
# Out:
#                        name             job_title  salary            name  \
# employee_id
# 1             Michael Scott      Regional Manager  100000   Michael Scott
# 2               Jim Halpert  Sales Representative   60000     Jim Halpert
# 3                Pam Beesly          Receptionist   55000      Pam Beesly
# 5             Angela Martin    Head of Accounting   60000   Angela Martin
# 6              Kevin Malone            Accountant   55000    Kevin Malone
# 7            Oscar Martinez            Accountant   55000  Oscar Martinez
# 8            Stanley Hudson  Sales Representative   60000  Stanley Hudson
#
#              department
# employee_id
# 1            Management
# 2                 Sales
# 3             Reception
# 5            Accounting
# 6            Accounting
# 7            Accounting
# 8                 Sales

# %%
pd.concat([df1,df2], axis=0)
# Out:
#    employee_id            name                          job_title    salary  \
# 0            1   Michael Scott                   Regional Manager  100000.0
# 1            2     Jim Halpert               Sales Representative   60000.0
# 2            3      Pam Beesly                       Receptionist   55000.0
# 3            4  Dwight Schrute  Assistant to the Regional Manager   65000.0
# 4            5   Angela Martin                 Head of Accounting   60000.0
# 5            6    Kevin Malone                         Accountant   55000.0
# 6            7  Oscar Martinez                         Accountant   55000.0
# 7            8  Stanley Hudson               Sales Representative   60000.0
# 0            1   Michael Scott                                NaN       NaN
# 1            2     Jim Halpert                                NaN       NaN
# 2            3      Pam Beesly                                NaN       NaN
# 3            5   Angela Martin                                NaN       NaN
# 4            6    Kevin Malone                                NaN       NaN
# 5            7  Oscar Martinez                                NaN       NaN
# 6            8  Stanley Hudson                                NaN       NaN
# 7            9   Phyllis Vance                                NaN       NaN
#
#    department
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 0  Management
# 1       Sales
# 2   Reception
# 3  Accounting
# 4  Accounting
# 5  Accounting
# 6       Sales
# 7       Sales

# %%
pd.concat([df1,df2.rename(columns={'department':'job_title'})], axis=0)
# Out:
#    employee_id            name                          job_title    salary
# 0            1   Michael Scott                   Regional Manager  100000.0
# 1            2     Jim Halpert               Sales Representative   60000.0
# 2            3      Pam Beesly                       Receptionist   55000.0
# 3            4  Dwight Schrute  Assistant to the Regional Manager   65000.0
# 4            5   Angela Martin                 Head of Accounting   60000.0
# 5            6    Kevin Malone                         Accountant   55000.0
# 6            7  Oscar Martinez                         Accountant   55000.0
# 7            8  Stanley Hudson               Sales Representative   60000.0
# 0            1   Michael Scott                         Management       NaN
# 1            2     Jim Halpert                              Sales       NaN
# 2            3      Pam Beesly                          Reception       NaN
# 3            5   Angela Martin                         Accounting       NaN
# 4            6    Kevin Malone                         Accounting       NaN
# 5            7  Oscar Martinez                         Accounting       NaN
# 6            8  Stanley Hudson                              Sales       NaN
# 7            9   Phyllis Vance                              Sales       NaN

# %%
result = pd.concat([df1[['employee_id','name']],df2[['employee_id','name']]], axis=0)

# %%
result.drop_duplicates(keep='first').reset_index().drop(columns='index')
# Out:
#    employee_id            name
# 0            1   Michael Scott
# 1            2     Jim Halpert
# 2            3      Pam Beesly
# 3            4  Dwight Schrute
# 4            5   Angela Martin
# 5            6    Kevin Malone
# 6            7  Oscar Martinez
# 7            8  Stanley Hudson
# 8            9   Phyllis Vance

# %%
pd.concat([df1,df2], axis=0, ignore_index=True)
# Out:
#     employee_id            name                          job_title    salary  \
# 0             1   Michael Scott                   Regional Manager  100000.0
# 1             2     Jim Halpert               Sales Representative   60000.0
# 2             3      Pam Beesly                       Receptionist   55000.0
# 3             4  Dwight Schrute  Assistant to the Regional Manager   65000.0
# 4             5   Angela Martin                 Head of Accounting   60000.0
# 5             6    Kevin Malone                         Accountant   55000.0
# 6             7  Oscar Martinez                         Accountant   55000.0
# 7             8  Stanley Hudson               Sales Representative   60000.0
# 8             1   Michael Scott                                NaN       NaN
# 9             2     Jim Halpert                                NaN       NaN
# 10            3      Pam Beesly                                NaN       NaN
# 11            5   Angela Martin                                NaN       NaN
# 12            6    Kevin Malone                                NaN       NaN
# 13            7  Oscar Martinez                                NaN       NaN
# 14            8  Stanley Hudson                                NaN       NaN
# 15            9   Phyllis Vance                                NaN       NaN
#
#     department
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8   Management
# 9        Sales
# 10   Reception
# 11  Accounting
# 12  Accounting
# 13  Accounting
# 14       Sales
# 15       Sales

# %%
result.drop_duplicates(keep='first').reset_index(drop=True)
# Out:
#    employee_id            name
# 0            1   Michael Scott
# 1            2     Jim Halpert
# 2            3      Pam Beesly
# 3            4  Dwight Schrute
# 4            5   Angela Martin
# 5            6    Kevin Malone
# 6            7  Oscar Martinez
# 7            8  Stanley Hudson
# 8            9   Phyllis Vance

# %%
pd.concat([df1,df2], axis=0, keys=['df_1','df_2'])
# Out:
#         employee_id            name                          job_title  \
# df_1 0            1   Michael Scott                   Regional Manager
#      1            2     Jim Halpert               Sales Representative
#      2            3      Pam Beesly                       Receptionist
#      3            4  Dwight Schrute  Assistant to the Regional Manager
#      4            5   Angela Martin                 Head of Accounting
#      5            6    Kevin Malone                         Accountant
#      6            7  Oscar Martinez                         Accountant
#      7            8  Stanley Hudson               Sales Representative
# df_2 0            1   Michael Scott                                NaN
#      1            2     Jim Halpert                                NaN
#      2            3      Pam Beesly                                NaN
#      3            5   Angela Martin                                NaN
#      4            6    Kevin Malone                                NaN
#      5            7  Oscar Martinez                                NaN
#      6            8  Stanley Hudson                                NaN
#      7            9   Phyllis Vance                                NaN
#
#           salary  department
# df_1 0  100000.0         NaN
#      1   60000.0         NaN
#      2   55000.0         NaN
#      3   65000.0         NaN
#      4   60000.0         NaN
#      5   55000.0         NaN
#      6   55000.0         NaN
#      7   60000.0         NaN
# df_2 0       NaN  Management
#      1       NaN       Sales
#      2       NaN   Reception
#      3       NaN  Accounting
#      4       NaN  Accounting
#      5       NaN  Accounting
#      6       NaN       Sales
#      7       NaN       Sales
